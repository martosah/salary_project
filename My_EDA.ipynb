# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",None)

# %%
data=pd.read_csv("data_clean.csv")

# %%
data.head()
# Out:
#                    Job Title Salary Estimate  Job Description  Rating  \
# 0             Data Scientist          53-91              2536     3.8
# 1  Healthcare Data Scientist         63-112              4783     3.4
# 2             Data Scientist          80-90              3461     4.8
# 3             Data Scientist          56-97              3883     3.8
# 4             Data Scientist         86-143              2728     2.9
#
#                             Company Name Location    Headquarters  \
# 0                      Tecolote Research       NM      Goleta, CA
# 1  University of Maryland Medical System       MD   Baltimore, MD
# 2                                KnowBe4       FL  Clearwater, FL
# 3                                   PNNL       WA    Richland, WA
# 4                     Affinity Solutions       NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# ...

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'minsal', 'maxsal', 'Average_salary', 'Job in HQ', 'Company_age',
#        'python', 'sql', 'spark', 'excel', 'IT', 'R', 'Entry_level',
#        'Competitors_cnt', 'Jobtitle_cat', 'Jobtitle_grp', 'Experience_level'],
#       dtype='object')

# %%
#data=data.drop(columns=["Job Title","Salary Estimate","Revenue","Sector","Jobtitle_cat","Size","Competitors","Headquarters","Founded","Type of ownership","Industry"])

# %%
data.describe()
# Out:
#        Job Description      Rating      Founded      minsal      maxsal  \
# count       742.000000  742.000000   742.000000  742.000000  742.000000
# mean       3869.545822    3.633693  1837.154987   74.068733  127.183288
# std        1521.495868    0.720715   497.183763   31.869282   46.909006
# min         407.000000    0.000000    -1.000000   10.000000   16.000000
# 25%        2801.000000    3.300000  1939.000000   52.000000   96.000000
# 50%        3731.000000    3.700000  1988.000000   69.500000  124.000000
# 75%        4740.000000    4.000000  2007.000000   91.000000  155.000000
# max       10051.000000    5.000000  2019.000000  202.000000  306.000000
#
#        Average_salary   Job in HQ  Company_age      python         sql  \
# count      742.000000  742.000000   742.000000  742.000000  742.000000
# mean       100.626011    0.681941    47.591644    0.528302    0.512129
# std         38.855948    0.466037    53.778815    0.499535    0.500190
# ...

# %%
data["Rating"].hist()
# Out:
# <AxesSubplot:>

# %%
data["Company_age"].hist()
# Out:
# <AxesSubplot:>

# %%
data["Average_salary"].hist()
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column="Average_salary")
plt.ylabel("Count")
plt.show()

# %%
data.boxplot(column="Job Description")
plt.ylabel("Count")
plt.show()

# %%
sb.scatterplot(x=data["Job Description"],y=data["Average_salary"],hue=data["python"])
plt.show()

# %%
sb.scatterplot(x=data["Rating"],y=data["Average_salary"],hue=data["python"])
plt.show()

# %%
sb.scatterplot(x=data["Company_age"],y=data["Average_salary"])
plt.show()

# %%
data.dtypes
# Out:
# Job Title             object
# Salary Estimate       object
# Job Description        int64
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded                int64
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# minsal                 int64
# maxsal                 int64
# Average_salary       float64
# Job in HQ              int64
# Company_age            int64
# python                 int64
# sql                    int64
# spark                  int64
# excel                  int64
# IT                     int64
# R                      int64
# Entry_level            int64
# Competitors_cnt        int64
# Jobtitle_cat          object
# Jobtitle_grp          object
# Experience_level      object
# dtype: object

# %%
num_feat=[i for i in data.columns if data[i].dtypes !="O"]

# %%
cont_feat=[i for i in num_feat if len(data[i].unique())>25]

# %%
cont_feat
# Out:
# ['Job Description',
#  'Rating',
#  'Founded',
#  'minsal',
#  'maxsal',
#  'Average_salary',
#  'Company_age']

# %%
plt.figure(figsize=(10,10))

sb.heatmap(data[num_feat].corr(),annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# ### Categorical Variable

# %%
cat_feat=[i for i in data.columns if i not in num_feat]

# %%
cat_feat
# Out:
# ['Job Title',
#  'Salary Estimate',
#  'Company Name',
#  'Location',
#  'Headquarters',
#  'Size',
#  'Type of ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Competitors',
#  'Jobtitle_cat',
#  'Jobtitle_grp',
#  'Experience_level']

# %%
data["Company Name"].value_counts()[:20]
# Out:
# Reynolds American                                  14
# MassMutual                                         14
# Takeda Pharmaceuticals                             14
# Software Engineering Institute                     11
# PNNL                                               10
# Liberty Mutual Insurance                           10
# AstraZeneca                                         9
# MITRE                                               8
# Pfizer                                              7
# Novartis                                            7
# Numeric, LLC                                        7
# Advanced BioScience Laboratories                    7
# Fareportal                                          7
# Rochester Regional Health                           7
# Beebe Healthcare                                    6
# Q2 Solutions                                        6
# The Church of Jesus Christ of Latter-day Saints     6
# ...

# %%
data.loc[data["Company Name"]=="Reynolds American"]
# Out:
#                                              Job Title Salary Estimate  \
# 331   Scientist Manufacturing - Kentucky BioProcessing         68-139
# 358                    Scientist - Analytical Services         65-134
# 364          Senior Scientist - Regulatory Submissions         80-155
# 393  Scientist Manufacturing Pharma - Kentucky BioP...         68-139
# 413  Senior Scientist - Toxicologist - Product Inte...         47-101
# 421                 Senior Scientist - Biostatistician          65-96
# 478   Scientist Manufacturing - Kentucky BioProcessing         68-139
# 534                    Scientist - Analytical Services         65-134
# 543          Senior Scientist - Regulatory Submissions         80-155
# 596  Scientist Manufacturing Pharma - Kentucky BioP...         68-139
# 622  Senior Scientist - Toxicologist - Product Inte...         47-101
# 636                 Senior Scientist - Biostatistician          65-96
# ...

# %%
for i in cat_feat:
        
        sb.barplot(x=data[i].value_counts()[:20].index, y=data[i].value_counts()[:20])
        plt.xticks(rotation='vertical')
        plt.show()

# %%
pd.pivot_table(data,index="Jobtitle_grp",values="Average_salary").sort_values(by="Average_salary",ascending=False)
# Out:
#                   Average_salary
# Jobtitle_grp
# director              168.607143
# machine learning      126.431818
# data scientist        117.564516
# data engineer         105.403361
# na                     84.853261
# manager                84.022727
# data analyst           65.857843

# %%
pd.pivot_table(data,index=["Jobtitle_grp","Experience_level"],values="Average_salary")
# Out:
#                                    Average_salary
# Jobtitle_grp     Experience_level
# data analyst     junior                 56.500000
#                  na                     65.467742
#                  senior                 71.562500
# data engineer    na                    100.380208
#                  senior                126.369565
# data scientist   junior                106.500000
#                  na                    112.927126
#                  senior                154.870968
# director         na                    168.607143
# machine learning na                    121.380952
#                  senior                232.500000
# manager          na                     84.022727
# na               na                     80.314935
#                  senior                108.150000

# %%
pd.set_option("display.max_rows",None)
pd.pivot_table(data,index=["Location","Jobtitle_grp"],values="Average_salary").sort_values(by=["Location"])
# Out:
#                            Average_salary
# Location Jobtitle_grp
# AL       data analyst           62.200000
#          data engineer          65.000000
#          na                     43.750000
# AZ       data analyst           55.000000
#          data engineer          79.500000
#          data scientist         69.500000
#          na                    124.500000
# CA       manager                80.611111
#          machine learning      177.300000
#          na                     99.907407
#          data engineer         129.540000
#          data analyst           85.250000
#          data scientist        142.522059
# CO       data analyst           29.500000
#          data engineer          99.000000
#          data scientist        108.666667
#          machine learning      100.500000
#          na                     31.500000
# CT       data scientist         84.000000
#          na                     62.500000
# DC       data analyst           63.500000
# ...

# %%
## Which state is paying mle more?

# %%
pd.pivot_table(data.loc[data["Jobtitle_grp"]=="machine learning"],index=["Location"],values=["Average_salary"]).sort_values("Average_salary",ascending=False)
# Out:
#           Average_salary
# Location
# CA                 177.3
# IL                 133.0
# NY                 125.0
# PA                 120.5
# CO                 100.5
# KS                  87.0
# VA                  87.0

# %%
#Salary by rating
#Salary by number of competition
#Salary by Description length
#Salary by

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'minsal', 'maxsal', 'Average_salary', 'Job in HQ', 'Company_age',
#        'python', 'sql', 'spark', 'excel', 'IT', 'R', 'Entry_level',
#        'Competitors_cnt', 'Jobtitle_cat', 'Jobtitle_grp', 'Experience_level'],
#       dtype='object')

# %%
hj=data[["Industry","Type of ownership","Experience_level","Average_salary","Competitors_cnt",'python', 'sql', 'spark', 'excel', 'IT', 'R','Sector', 'Revenue']]

# %%
pd.pivot_table(hj,index="Type of ownership",values="Average_salary").sort_values("Average_salary",ascending=False)
# Out:
#                                 Average_salary
# Type of ownership
# -1                                  117.500000
# Company - Public                    110.893782
# Subsidiary or Business Segment      110.573529
# College / University                107.615385
# Company - Private                   101.776829
# Government                           84.300000
# School / School District             77.750000
# Other Organization                   77.500000
# Nonprofit Organization               68.281818
# Hospital                             54.000000
# Unknown                              39.500000

# %%
for i in hj.columns:
    if i =="Average_salary":
        pass
    else:
        print(pd.pivot_table(hj,index=i,values="Average_salary").sort_values("Average_salary",ascending=False))
# Out:
#                                           Average_salary
# Industry
# Other Retail Stores                           163.500000
# Motion Picture Production & Distribution      146.000000
# Financial Analytics & Research                145.125000
# Health, Beauty, & Fitness                     139.500000
# Telecommunications Services                   131.500000
# Brokerage Services                            129.000000
# Auctions & Galleries                          128.000000
# Internet                                      123.810345
# Investment Banking & Asset Management         118.400000
# TV Broadcast & Cable Networks                 117.750000
# Enterprise Software & Network Solutions       115.369048
# Computer Hardware & Software                  115.194915
# -1                                            114.650000
# Accounting                                    113.500000
# Biotech & Pharmaceuticals                     111.767857
# ...

# %%
for i in data.columns:
    if i =="Average_salary":
        pass
    else:
        print(pd.pivot_table(data,index=i,values="Average_salary").sort_values("Average_salary",ascending=False))
# Out:
#                                                     Average_salary
# Job Title
# Director II, Data Science - GRM Actuarial               254.000000
# Principal Machine Learning Scientist                    232.500000
# Principal Data Scientist with over 10 years exp...      225.000000
# Lead Data Engineer                                      205.000000
# Director II, Data Science - GRS Predictive Anal...      194.500000
# Staff Machine Learning Engineer                         181.000000
# Director, Data Science                                  179.500000
# Principal Data Scientist                                176.300000
# Sr. Scientist II                                        174.000000
# Senior Quantitative Analyst                             173.000000
# Data Scientist - Alpha Insights                         172.000000
# Director, Precision Medicine Clinical Biomarker...      172.000000
# Staff Data Scientist                                    171.500000
# ...

# %%
for i in data.columns:
    if i =="Average_salary":
        pass
    else:
        print(pd.pivot_table(data,index=i,values="Average_salary",aggfunc="count").sort_values("Average_salary",ascending=False))
# Out:
#                                                     Average_salary
# Job Title
# Data Scientist                                                 131
# Data Engineer                                                   53
# Senior Data Scientist                                           34
# Data Analyst                                                    15
# Senior Data Engineer                                            14
# Senior Data Analyst                                             12
# Lead Data Scientist                                              8
# Sr. Data Engineer                                                6
# Marketing Data Analyst                                           6
# Principal Data Scientist                                         5
# Machine Learning Engineer                                        5
# MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB                        4
# Analytics Manager - Data Mart                                    4
# ...

# %%
pd.pivot_table(data,index="Jobtitle_grp",values="Average_salary").sort_values("Average_salary",ascending=False)[:3]
# Out:
#                   Average_salary
# Jobtitle_grp
# director              168.607143
# machine learning      126.431818
# data scientist        117.564516

# %%
pd.pivot_table(data,index="Revenue",columns="python",values="Average_salary",aggfunc="count")
# Out:
# python                               0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0
